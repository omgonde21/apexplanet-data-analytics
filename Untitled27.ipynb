# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Sabse pehle apna data load karo (apni file ka sahi naam/path yahan likho)
# Agar aapki file ka naam 'cleaned_ecommerce.csv' hai toh:
df = pd.read_csv('cleaned_ecommerce.csv')

# 2. InvoiceDate column ko datetime format mein convert karna zaroori hai
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# 3. Ab month extract karo aur group karo
df['Month'] = df['InvoiceDate'].dt.strftime('%B')
months_order = ['January', 'February', 'March', 'April', 'May', 'June',
                'July', 'August', 'September', 'October', 'November', 'December']

monthly_sales = df.groupby('Month')['TotalAmount'].sum().reindex(months_order).reset_index()

# 4. Plotting Line Chart
plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_sales, x='Month', y='TotalAmount', marker='o', color='#0A2540', linewidth=2.5)

plt.title('Sum of TotalAmount by Month', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sum of TotalAmount', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save image for GitHub
plt.savefig('monthly_sales_trend.png', dpi=300)
plt.show()

# %%
# 1. Top 5 ya 10 products group karna
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(6).reset_index()

# 2. Plotting
plt.figure(figsize=(10, 5))
sns.barplot(data=top_products, x='Quantity', y='Description', color='#002060')

plt.title('Sum of Quantity by Description', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Sum of Quantity', fontsize=12)
plt.ylabel('Description', fontsize=12)
plt.tight_layout()

# Save image for GitHub
plt.savefig('top_products_quantity.png', dpi=300)
plt.show()

# %%
import plotly.express as px

# 1. Country wise sales aggregation
country_sales = df.groupby('Country')['TotalAmount'].sum().reset_index()

# 2. Interactive Treemap using Plotly
fig = px.treemap(country_sales,
                 path=['Country'],
                 values='TotalAmount',
                 title='Sum of TotalAmount by Country',
                 color='TotalAmount',
                 color_continuous_scale='Blues')

fig.update_layout(title_font=dict(size=18, family='Arial', color='black'))

# Save as HTML (Task 3 requirements ke mutabik)
fig.write_html("country_sales_treemap.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97a1cd71-4828-4885-9348-4d97c03e7db6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97a1cd71-4828-4885-9348-4d97c03e7db6")) {                    Plotly.newPlot(                        "97a1cd71-4828-4885-9348-4d97c03e7db6",                        [{"branchvalues":"total","customdata":[[138521.31],[10198.68],[548.4],[41196.340000000004],[1143.6],[3666.38],[20450.44],[13590.380000000001],[826.74],[18955.34],[265545.9],[1300.25],[22546.08],[209024.05],[228867.14],[4760.52],[4310.0],[7221.69],[17483.24],[37416.37],[1693.8799999999999],[1661.06],[2725.59],[285446.34],[36165.44],[7334.65],[33439.89],[1002.3100000000001],[145.92000000000002],[21279.29],[61577.11],[38378.33],[56443.95],[3580.39],[1902.28],[7308391.5540000005],[2667.07]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eTotalAmount_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eTotalAmount=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Australia","Austria","Bahrain","Belgium","Brazil","Canada","Channel Islands","Cyprus","Czech Republic","Denmark","EIRE","European Community","Finland","France","Germany","Greece","Iceland","Israel","Italy","Japan","Lebanon","Lithuania","Malta","Netherlands","Norway","Poland","Portugal","RSA","Saudi Arabia","Singapore","Spain","Sweden","Switzerland","USA","United Arab Emirates","United Kingdom","Unspecified"],"labels":["Australia","Austria","Bahrain","Belgium","Brazil","Canada","Channel Islands","Cyprus","Czech Republic","Denmark","EIRE","European Community","Finland","France","Germany","Greece","Iceland","Israel","Italy","Japan","Lebanon","Lithuania","Malta","Netherlands","Norway","Poland","Portugal","RSA","Saudi Arabia","Singapore","Spain","Sweden","Switzerland","USA","United Arab Emirates","United Kingdom","Unspecified"],"marker":{"coloraxis":"coloraxis","colors":[138521.31,10198.68,548.4,41196.340000000004,1143.6,3666.38,20450.44,13590.380000000001,826.74,18955.34,265545.9,1300.25,22546.08,209024.05,228867.14,4760.52,4310.0,7221.69,17483.24,37416.37,1693.8799999999999,1661.06,2725.59,285446.34,36165.44,7334.65,33439.89,1002.3100000000001,145.92000000000002,21279.29,61577.11,38378.33,56443.95,3580.39,1902.28,7308391.5540000005,2667.07]},"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[138521.31,10198.68,548.4,41196.340000000004,1143.6,3666.38,20450.44,13590.380000000001,826.74,18955.34,265545.9,1300.25,22546.08,209024.05,228867.14,4760.52,4310.0,7221.69,17483.24,37416.37,1693.88,1661.06,2725.59,285446.34,36165.44,7334.65,33439.89,1002.3100000000001,145.92000000000002,21279.29,61577.11,38378.33,56443.95,3580.39,1902.28,7308391.5540000005,2667.07],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heat ...
